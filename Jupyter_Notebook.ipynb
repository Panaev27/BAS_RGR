# %% [markdown]
# # Заголовок первого уровня
# ## Заголовок второго уровня
# ### Заголовок третьго уровня
# #Греческий алфавит
# | Заглавная     | Строчная      | Название  |
# | ------------- |:-------------:| ---------:|
# | A             | $\alpha$      |  альфа    |
# | Β             | $\beta$       |  бета     |
# | Γ             | $\Gamma$      |  гамма    |
# | Δ             | $\Delta$      |  дельта   |
# | Ε             | $\epsilon$    |  эпсилон  |
# | Ζ             | $\zeta$       |  дзета    |
# | Η             | $\eta$        |  ита      |
# | Θ             | $\theta$      |  тета     |
# | Ι             | $\iota$       |  йота     |
# | Κ             | $\kappa$      |  каппа    |
# | Λ             | $\lambda$     |  лямбда   |
# | Μ             | $\mu$         |  мю       |
# | Ν             | $\nu$         |  ню       |
# | Ξ             | $\xi$         |  кси      |
# | Ο             | $\omicron$    |  омикрон  |
# | Π             | $\pi$         |  пи       |
# | rho           | $\rho$        |  ро       |
# | Σ             | $\sigma$      |  сигма    |
# | Τ             | $\tau$        |  тау      |
# | Υ             | $\upsilon$    |  ипсилон  |
# | Φ             | $\phi$        |  фи       |
# | Χ             | $\chi$        |  хи       |
# | Ψ             | $\psi$        |  пси      |
# | Ω             | $\omega$      |  омега    |
#
# Формула в отдельной строке: $${\displaystyle f(x)={\frac {1}{\sigma {\sqrt {2\pi }}}}e^{-{\frac {1}{2}}
# \left({\frac {x-\mu }{\sigma }}\right)^{2}}}$$
#
# Формула в тексте: ${\displaystyle f(x)={\frac {1}{\sigma {\sqrt {2\pi }}}}e^
# {-{\frac {1}{2}}\left({\frac {x-\mu }{\sigma }}\right)^{2}}}$
